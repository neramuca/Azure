# %%
from pyspark.sql.functions import expr
from pyspark.sql.functions import from_unixtime

events = spark.read \
  .option("inferSchema", "true")\
  .json("/databricks-datasets/structured-streaming/events/")\
  .withColumn("date", expr("time"))\
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))\
  .withColumn("Anio", expr("substring(date,1,4)"))\
  .withColumn("Mes", expr("substring(date,6,2)"))\
  .drop("time") 

display(events)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>Anio</th><th>Mes</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-28</td><td>2016</td><td>07</td></tr><tr><td>Open</td>< ...

# %%
events.write.format("delta").mode("overwrite").partitionBy("Anio").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("dbfs:/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/delta/events/Anio=2016/&apos;, name=&apos;Anio=2016/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/delta/events/_delta_log/&apos;, name=&apos;_delta_log/&apos;, size=0)]
# </div>

# %%
# %fs
rm -r "dbfs:/delta/events/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res3: Boolean = true
# </div>

# %%
events_delta = spark.read.format("delta").load("/delta/events/")

display(events_delta)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>Anio</th><th>Mes</th></tr></thead><tbody><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-27</td><td>2016</td><td>07</td></tr><tr><td> ...

# %%
display(spark.sql("DROP TABLE IF EXISTS events"))

display(spark.sql("CREATE TABLE events USING DELTA LOCATION '/delta/events/'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">27</span><span class="ansired">]: </span>100000
# </div>

# %%
from pyspark.sql.functions import count
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-26</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-26</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
historical_events = spark.read \
  .option("inferSchema", "true") \
  .json("/databricks-datasets/structured-streaming/events/") \
  .withColumn("date", expr("time-172800")) \
  .drop("time") \
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))\
  .withColumn("Anio", expr("substring(date,1,4)"))\
  .withColumn("Mes", expr("substring(date,6,2)"))
display(historical_events)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>Anio</th><th>Mes</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Close</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td><td>2016-07-26</td><td>2016</td><td>07</td></tr><tr><td>Open</td>< ...

# %%
historical_events.write.format("delta").mode("append").partitionBy("Anio").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.fs.ls("dbfs:/delta/events/")
events_delta = spark.read.format("delta").load("/delta/events/")
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">34</span><span class="ansired">]: </span>200000
# </div>

# %%
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-24</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-24</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-25</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-25</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-26</td><td>25985</td></tr><tr><td>Open</td><td>2016-07-26</td><td>25998</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">36</span><span class="ansired">]: </span>200000
# </div>

# %%
dbutils.fs.ls("dbfs:/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">37</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/delta/events/Anio=2016/&apos;, name=&apos;Anio=2016/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/delta/events/_delta_log/&apos;, name=&apos;_delta_log/&apos;, size=0)]
# </div>

# %%
#Borrar los datos cargados en events
# %fs
rm -r "dbfs:/delta/events/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = true
# </div>

# %%
display(spark.sql("OPTIMIZE events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>null</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE HISTORY events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th></tr></thead><tbody><tr><td>2</td><td>2019-06-17T09:05:06.000+0000</td><td>4372415976254024</td><td>emunozcar@dragosolutions.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0, auto -> false)</td><td>null</td><td>List(2131966090072072)</td><td>0503-100013-pins355</td><td>1</td><td>SnapshotIsolation</td></tr><tr><td>1</td><td>2019-06-17T09:01:34.000+0000</td><td>4372415976254024</td><td>emunozcar@dragosolutions.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> ["Anio"])</td><td>null</td><td>List(2131966090072072)</td><td>0503-100013-pins355</td><td>0</td><td>WriteSerializable</td></tr><tr><td>0</td><td>2019-06-17T08:49:01.000+0000</td><td>4372415976254024</td><td>emunozcar@dragosolutions.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> ["Anio"])</td><td>null</td><td>List(2131966090072072)</td><td>0503-100013-pins355</td><td>null</td><td>WriteSerializable</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE DETAIL events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>38206e73-7443-4958-9c05-2650abfb8bdd</td><td>null</td><td>null</td><td>dbfs:/delta/events</td><td>2019-06-17T08:48:56.498+0000</td><td>2019-06-17T09:05:06.000+0000</td><td>List(Anio)</td><td>1</td><td>26334</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE FORMATTED events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>action</td><td>string</td><td>null</td></tr><tr><td>date</td><td>string</td><td>null</td></tr><tr><td>Anio</td><td>string</td><td>null</td></tr><tr><td>Mes</td><td>string</td><td>null</td></tr><tr><td># Partition Information</td><td></td><td></td></tr><tr><td># col_name</td><td>data_type</td><td>comment</td></tr><tr><td>Anio</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>events</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Mon Jun 17 08:49:35 UTC 2019</td><td></td></tr><tr><td>Last Access</td><td>Thu Jan 01 00:00:00 UTC 1970</td><td></td></tr><tr><td>Created By</td><td>Spark 2.4.0</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>DELTA</td><td></td></tr><tr><td>Location</td><td>dbfs:/delta/events</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.SequenceFileInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveSequenceFileOutputFormat</td><td></td></tr></tbody></table></div>
