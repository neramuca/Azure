# %%
from pyspark.sql.functions import expr
from pyspark.sql.functions import from_unixtime

events = spark.read \
  .option("inferSchema", "true") \
  .json("/databricks-datasets/structured-streaming/events/") \
  .withColumn("date", expr("time")) \
  .drop("time") \
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))
  
display(events)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016- ...

# %%
events.write.format("delta").mode("overwrite").partitionBy("date").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
events_delta = spark.read.format("delta").load("/delta/events/")

display(events_delta)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016-07-28</td></tr><tr><td>Close</td><td>2016-07-28</td></tr><tr><td>Open</td><td>2016- ...

# %%
display(spark.sql("DROP TABLE IF EXISTS events"))

display(spark.sql("CREATE TABLE events USING DELTA LOCATION '/delta/events/'"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">35</span><span class="ansired">]: </span>100000
# </div>

# %%
from pyspark.sql.functions import count
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-26</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-26</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
historical_events = spark.read \
  .option("inferSchema", "true") \
  .json("/databricks-datasets/structured-streaming/events/") \
  .withColumn("date", expr("time-172800")) \
  .drop("time") \
  .withColumn("date", from_unixtime("date", 'yyyy-MM-dd'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
historical_events.write.format("delta").mode("append").partitionBy("date").save("/delta/events/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(events_delta.groupBy("action","date").agg(count("action").alias("action_count")).orderBy("date", "action"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>action</th><th>date</th><th>action_count</th></tr></thead><tbody><tr><td>Close</td><td>2016-07-24</td><td>20165</td></tr><tr><td>Open</td><td>2016-07-24</td><td>21176</td></tr><tr><td>Close</td><td>2016-07-25</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-25</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-26</td><td>25985</td></tr><tr><td>Open</td><td>2016-07-26</td><td>25998</td></tr><tr><td>Close</td><td>2016-07-27</td><td>24015</td></tr><tr><td>Open</td><td>2016-07-27</td><td>24002</td></tr><tr><td>Close</td><td>2016-07-28</td><td>5820</td></tr><tr><td>Open</td><td>2016-07-28</td><td>4822</td></tr></tbody></table></div>

# %%
events_delta.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">40</span><span class="ansired">]: </span>200000
# </div>

# %%
dbutils.fs.ls("dbfs:/delta/events/date=2016-07-25/")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">41</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00000-502f5456-cc97-46a3-a206-5290d5b063b2.c000.snappy.parquet&apos;, name=&apos;part-00000-502f5456-cc97-46a3-a206-5290d5b063b2.c000.snappy.parquet&apos;, size=1392),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00001-d4f44123-61cd-4e9f-b741-f1dbc4245176.c000.snappy.parquet&apos;, name=&apos;part-00001-d4f44123-61cd-4e9f-b741-f1dbc4245176.c000.snappy.parquet&apos;, size=1724),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00002-1a528d9f-034a-4e7b-9320-f0d8f67597e3.c000.snappy.parquet&apos;, name=&apos;part-00002-1a528d9f-034a-4e7b-9320-f0d8f67597e3.c000.snappy.parquet&apos;, size=962),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00003-fd2a5553-ecc4-4f22-9eda-50befcf845c5.c000.snappy.parquet&apos;, name=&apos;part-00003-fd2a5553-ecc4-4f22-9eda-50befcf845c5.c000.snappy.parquet&apos;, size=958),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00004-2e9178ec-76aa-4ee3-8e78-7036cd47b5a7.c000.snappy.parquet&apos;, name=&apos;part-00004-2e9178ec-76aa-4ee3-8e78-7036cd47b5a7.c000.snappy.parquet&apos;, size=959),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00005-6058229f-65eb-446f-9851-c142f89a8977.c000.snappy.parquet&apos;, name=&apos;part-00005-6058229f-65eb-446f-9851-c142f89a8977.c000.snappy.parquet&apos;, size=1813),
#  FileInfo(path=&apos;dbfs:/delta/events/date=2016-07-25/part-00006-3b495912-22b3-4498-964a-3937f27a79ec.c000.snappy.parquet&apos;, name=&apos;part-00006-3b495912-22b3-4498-964a-3937f27a79ec.c000.snappy.parquet&apos;, size=1470)]
# </div>

# %%
display(spark.sql("OPTIMIZE events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td>null</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE HISTORY events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th></tr></thead><tbody><tr><td>2</td><td>2019-01-29 00:38:19</td><td>360903564160648</td><td>stephanie.bodoff@databricks.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(2433269420249641)</td><td>0125-221106-miaow213</td><td>1</td><td>SnapshotIsolation</td></tr><tr><td>1</td><td>2019-01-29 00:38:10</td><td>360903564160648</td><td>stephanie.bodoff@databricks.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> ["date"])</td><td>null</td><td>List(2433269420249641)</td><td>0125-221106-miaow213</td><td>0</td><td>WriteSerializable</td></tr><tr><td>0</td><td>2019-01-29 00:37:58</td><td>360903564160648</td><td>stephanie.bodoff@databricks.com</td><td>WRITE</td><td>Map(mode -> Overwrite, partitionBy -> ["date"])</td><td>null</td><td>List(2433269420249641)</td><td>0125-221106-miaow213</td><td>null</td><td>WriteSerializable</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE DETAIL events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th></tr></thead><tbody><tr><td>delta</td><td>f7b17b8a-67db-4822-a4dc-c2a19c577357</td><td>null</td><td>null</td><td>dbfs:/delta/events</td><td>2019-01-29 00:37:55.795</td><td>2019-01-29 00:38:19</td><td>List(date)</td><td>5</td><td>27683</td><td>Map()</td><td>1</td><td>2</td></tr></tbody></table></div>

# %%
display(spark.sql("DESCRIBE FORMATTED events"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>action</td><td>string</td><td>null</td></tr><tr><td>date</td><td>string</td><td>null</td></tr><tr><td># Partition Information</td><td></td><td></td></tr><tr><td># col_name</td><td>data_type</td><td>comment</td></tr><tr><td>date</td><td>string</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Database</td><td>default</td><td></td></tr><tr><td>Table</td><td>events</td><td></td></tr><tr><td>Owner</td><td>root</td><td></td></tr><tr><td>Created Time</td><td>Tue Jan 29 00:38:03 UTC 2019</td><td></td></tr><tr><td>Last Access</td><td>Thu Jan 01 00:00:00 UTC 1970</td><td></td></tr><tr><td>Created By</td><td>Spark 2.4.0</td><td></td></tr><tr><td>Type</td><td>EXTERNAL</td><td></td></tr><tr><td>Provider</td><td>DELTA</td><td></td></tr><tr><td>Location</td><td>dbfs:/delta/events</td><td></td></tr><tr><td>Serde Library</td><td>org.apache.hadoop.hive.serde2.lazy.LazySimpleSerDe</td><td></td></tr><tr><td>InputFormat</td><td>org.apache.hadoop.mapred.SequenceFileInputFormat</td><td></td></tr><tr><td>OutputFormat</td><td>org.apache.hadoop.hive.ql.io.HiveSequenceFileOutputFormat</td><td></td></tr></tbody></table></div>
