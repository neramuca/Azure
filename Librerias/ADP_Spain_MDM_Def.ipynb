# %%
# %run "./ADP_Load_Conf"

# %%
# %run "./UTL_Gen"

# %%
# %run "./UTL_Blob"

# %%
################################################################################
"""Spain Master Data PMS's File Utils.

"""
 #Who                 When           What
 #Victor Salesa       16/10/2018     Initial version
 #Victor Salesa       17/10/2018     Added NATIONAL_CODE AND CONTROL_CODE TO THE 
 #                                    __SP_PRODUCT_CANONICAL_DATA_SCHEMA__
 #Ana Perez           25/10/2018     Added new fields (postal_code, ...) to the
 #                                    __SP_PHARMACIES_MASTER_DATA_SCHEMA__
 #Victor Salesa       02/10/2018     Changed schema for new file format 
 #Victor Salesa       23/01/2019     Changed source for PRODUCT MASTER DATA TO M_SP_PRODUCT_CAT.csv
 #                                   Changed destination for PRODUCT MASTER DATA TO M_SP_PRODUCT_CAT_CDM
 #                                   Changed source for CATEGORIES MASTER DATA TO M_SP_PRODUCT.csv 
 #                                   Changed destination for CATEGORIES MASTER DATA TO M_SP_PRODUCT_CDM
 #                                   Finish changing all masterdata sources and destinations
 #                                   Added __PRODUCT_FILENAME__,__PRODUCT_FILENAME_CANONICAL_,__PHARMATIC_MASTER_DATA_LANDING_PRODUCT_PATH__,__PHARMATIC_MASTER_DATA_CANONICAL_PRODUCT_PATH__
 #                                   Removed old PRODUCT/CATEGORIES/PHARMACIES/MANUFACTURER SCHEMAS AND SUBSTITUTED WITH __M_SP_PRODUCT_RAW_SCHEMA__ AND __M_SP_PRODUCT_CAT_RAW_SCHEMA__ AND __M_SP_PHARMACY_RAW_SCHEMA__ and 
 #                                   __M_SP_MANUFACTURER_RAW_SCHEMA__
 #Victor Salesa       06/03/2019    Added hive-parquet table names configuration __CATEGORIES_TABLE_NAME__ , __PRODUCT_TABLE_NAME__ , __PHARMACY_TABLE_NAME__ , __MANUFACTURERS_TABLE_NAME__ 
 #Victor Salesa       04/04/2019    Changed START_DATE and END_DATE to be date_val_yyyymmddHHmmss instead of date_val_ddmmyyyy 
 #Victor Salesa       06/05/2019    Included UTL_Blob Library 
 #Victor Salesa       06/05/2019    Added CUSTOMER Master Data Constants and __MDM_SP_FILE_PREFIX__ for filename validation
 #Victor Salesa       07/05/2019    MasterData Paths will be masterdataname*.csv so it doesn't depend on timestamp
 #Ana Perez           09/05/2019    Fix bug in __PHARMATIC_MASTER_DATA_LANDING_xxx_PATH__  definition
################################################################################

# Variables with defaulta characteristics when reading csv from spain

__SPAIN_MASTERDATA_CSV_DELIMITER__ = '|'
__SPAIN_MASTERDATA_CSV_MODE_ = 'FAILSAFE'

#----------- Master Data Paths


__CATEGORIES_FILENAME__             = 'M_SP_PRODUCT_CAT'
__CATEGORIES_FILENAME_CANONICAL_    = 'M_SP_PRODUCT_CAT_CDM'
__CATEGORIES_TABLE_NAME__           = 'ADP_M_PRODUCT_CAT'
__MDM_STG_M_PRODUCT_CAT_DB_TABLE_NAME__ ='ADP.STG_M_PRODUCT_CAT'

__PRODUCT_FILENAME__                = 'M_SP_PRODUCT'
__PRODUCT_FILENAME_CANONICAL_       = 'M_SP_PRODUCT_CDM'
__PRODUCT_TABLE_NAME__              = 'ADP_M_PRODUCT'
__MDM_STG_M_PRODUCT_DB_TABLE_NAME__ ='ADP.STG_M_PRODUCT'

__PHARMACIES_FILENAME__             = 'M_SP_PHARMACY'
__PHARMACIES_FILENAME_CANONICAL_    = 'M_SP_PHARMACY_CDM'
__PHARMACY_TABLE_NAME__             = 'ADP_M_PHARMACY'
__MDM_STG_M_PHARMACY_DB_TABLE_NAME__ ='ADP.STG_M_PHARMACY'

__MANUFACTURERS_FILENAME__          = 'M_SP_MANUFACTURER'
__MANUFACTURERS_FILENAME_CANONICAL_ = 'M_SP_MANUFACTURER_CDM'
__MANUFACTURERS_TABLE_NAME__        = 'ADP_M_MANUFACTURER'
__MDM_STG_M_MANUFACTURER_DB_TABLE_NAME__ ='ADP.STG_M_MANUFACTURER'

__CUSTOMER_FILENAME__               = 'M_SP_CUSTOMER'
__CUSTOMER_FILENAME_CANONICAL_      = 'M_SP_CUSTOMER_CDM'
__CUSTOMER_TABLE_NAME__             = 'ADP_M_CUSTOMER'

__MASTER_DATA_FILES_EXT__             = '.CSV'

__PHARMATIC_MASTER_DATA_LANDING_CATEGORIES_PATH__           = __MASTER_DATA_LANDING_BASE_PATH__       + __CATEGORIES_FILENAME__          +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_TOBEPROCESSED_CATEGORIES_PATH__     = __MASTER_DATA_TOBEPROCESSED_BASE_PATH__ + __CATEGORIES_FILENAME__          +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_CANONICAL_CATEGORIES_PATH__         = __MASTER_DATA_CANONICAL_BASE_PATH__     + __CATEGORIES_FILENAME_CANONICAL_

__PHARMATIC_MASTER_DATA_LANDING_PRODUCT_PATH__              = __MASTER_DATA_LANDING_BASE_PATH__       + __PRODUCT_FILENAME__             +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_TOBEPROCESSED_PRODUCT_PATH__        = __MASTER_DATA_TOBEPROCESSED_BASE_PATH__ + __PRODUCT_FILENAME__             +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_CANONICAL_PRODUCT_PATH__            = __MASTER_DATA_CANONICAL_BASE_PATH__     + __PRODUCT_FILENAME_CANONICAL_

__PHARMATIC_MASTER_DATA_LANDING_PHARMACIES_PATH__           = __MASTER_DATA_LANDING_BASE_PATH__       + __PHARMACIES_FILENAME__          +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_TOBEPROCESSED_PHARMACIES_PATH__     = __MASTER_DATA_TOBEPROCESSED_BASE_PATH__ + __PHARMACIES_FILENAME__          +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_CANONICAL_PHARMACIES_PATH__         = __MASTER_DATA_CANONICAL_BASE_PATH__     + __PHARMACIES_FILENAME_CANONICAL_

__PHARMATIC_MASTER_DATA_LANDING_MANUFACTURERS_PATH__        = __MASTER_DATA_LANDING_BASE_PATH__       + __MANUFACTURERS_FILENAME__       +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_TOBEPROCESSED_MANUFACTURERS_PATH__  = __MASTER_DATA_TOBEPROCESSED_BASE_PATH__ + __MANUFACTURERS_FILENAME__       +'_2*'+__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_CANONICAL_MANUFACTURERS_PATH__      = __MASTER_DATA_CANONICAL_BASE_PATH__     + __MANUFACTURERS_FILENAME_CANONICAL_

__PHARMATIC_MASTER_DATA_LANDING_CUSTOMER_PATH__        = __MASTER_DATA_LANDING_BASE_PATH__       + __CUSTOMER_FILENAME__       +__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_TOBEPROCESSED_CUSTOMER_PATH__  = __MASTER_DATA_TOBEPROCESSED_BASE_PATH__ + __CUSTOMER_FILENAME__       +__MASTER_DATA_FILES_EXT__
__PHARMATIC_MASTER_DATA_CANONICAL_CUSTOMER_PATH__      = __MASTER_DATA_CANONICAL_BASE_PATH__     + __CUSTOMER_FILENAME_CANONICAL_

__MDM_SP_FILE_PREFIX__ = [__CATEGORIES_FILENAME__,__PRODUCT_FILENAME__,__PHARMACIES_FILENAME__,__CUSTOMER_FILENAME__,__MANUFACTURERS_FILENAME__]

# Define the input schema for __M_SP_PHARMACY_RAW_SCHEMA__
__M_SP_PHARMACY_RAW_SCHEMA__ = StructType([
	StructField("PHARMACY_CODE",StringType(),True),
	StructField("PHARMACY_ADHERED_CODE",StringType(),True),
	StructField("PHARMACY_CUSTOMER_CODE",StringType(),True),
	StructField("POSTAL_CODE",StringType(),True),
	StructField("CITY",StringType(),True),
	StructField("PROVINCE",StringType(),True),
	StructField("COUNTRY_CODE",StringType(),True),
	StructField("LONGITUDE",StringType(),True),
	StructField("LATITUDE",StringType(),True),
	StructField("ALPHEGA_FLG",StringType(),True),
	StructField("SANIBRICK",StringType(),True),
	StructField("CIF",StringType(),True),
	StructField("PHARMACY_NAME",StringType(),True)
])

__M_SP_PHARMACY_CANONICAL_SCHEMA__ = __M_SP_PHARMACY_RAW_SCHEMA__

# Define the input schema for __M_SP_MANUFACTURER_RAW_SCHEMA__
__M_SP_MANUFACTURER_RAW_SCHEMA__ = StructType([	
	StructField("MANUFACTURER_CODE",StringType(),True),
	StructField("MANUFACTURER_NAME",StringType(),True)
])

__M_SP_MANUFACTURER_CANONICAL_SCHEMA__ = __M_SP_MANUFACTURER_RAW_SCHEMA__

# Define the input schema for __M_SP_PRODUCT_RAW_SCHEMA__
__M_SP_PRODUCT_RAW_SCHEMA__ = StructType([
  StructField("PRODUCT_INTERNAL_CODE",StringType(),True),
  StructField("PRODUCT_NATIONAL_CODE",StringType(),True),
  StructField("BAR_CODE",StringType(),True),
  StructField("PRODUCT_NAME",StringType(),True),
  StructField("PRODUCT_DESCRIPTION",StringType(),True),
  StructField("START_DATE",StringType(),True),
  StructField("END_DATE",StringType(),True),
  StructField("MANUFACTURER_CODE",StringType(),True),
  StructField("OWNBRAND_FLG",StringType(),True),
  StructField("OWNBRAND",StringType(),True),
  StructField("LEGAL_CATEGORY",StringType(),True),
  StructField("FAMILY",StringType(),True),
  StructField("IMS_CODE",StringType(),True),
  StructField("ATC_CODE",StringType(),True),
  StructField("LINKED_TO_PRODUCT",StringType(),True),
  StructField("REPLACED_BY_PRODUCT",StringType(),True),
  StructField("VAT_TYPE",StringType(),True),
  StructField("SALES_PRICE_MANUFACTURER",StringType(),True),
  StructField("SALES_PRICE_PHARMACY",StringType(),True),
  StructField("SALES_PRICE_PUBLIC",StringType(),True)
])

# Define the input schema for __M_SP_PRODUCT_RAW_SCHEMA__
__M_SP_PRODUCT_CANONICAL_SCHEMA__ = StructType([
  StructField("PRODUCT_INTERNAL_CODE",StringType(),True),
  StructField("PRODUCT_NATIONAL_CODE",StringType(),True),
  StructField("BAR_CODE",StringType(),True),
  StructField("PRODUCT_NAME",StringType(),True),
  StructField("PRODUCT_DESCRIPTION",StringType(),True),
  StructField("START_DATE",DateType(),True),
  StructField("END_DATE",DateType(),True),
  StructField("MANUFACTURER_CODE",StringType(),True),
  StructField("OWNBRAND_FLG",StringType(),True),
  StructField("OWNBRAND",StringType(),True),
  StructField("LEGAL_CATEGORY",StringType(),True),
  StructField("FAMILY",StringType(),True),
  StructField("IMS_CODE",StringType(),True),
  StructField("ATC_CODE",StringType(),True),
  StructField("LINKED_TO_PRODUCT",StringType(),True),
  StructField("REPLACED_BY_PRODUCT",StringType(),True),
  StructField("VAT_TYPE",StringType(),True),
  StructField("SALES_PRICE_MANUFACTURER",FloatType(),True),
  StructField("SALES_PRICE_PHARMACY",FloatType(),True),
  StructField("SALES_PRICE_PUBLIC",FloatType(),True)
])


# Define the input schema for __M_SP_PRODUCT_CAT_RAW_SCHEMA__
__M_SP_PRODUCT_CAT_RAW_SCHEMA__ = StructType([
	StructField("PRODUCT_INTERNAL_CODE",StringType(),True),
	StructField("BAR_CODE",StringType(),True),
	StructField("PRODUCT_NAME",StringType(),True),
	StructField("MANUFACTURER_CODE",StringType(),True),
	StructField("MANUFACTURER_NAME",StringType(),True),
	StructField("LEGAL_CATEGORY",StringType(),True),
	StructField("COMMERCIAL_CATEGORY_L1",StringType(),True),
	StructField("COMMERCIAL_CATEGORY_L2",StringType(),True),
	StructField("COMMERCIAL_CATEGORY_L3",StringType(),True),
	StructField("BRAND",StringType(),True)
])

__M_SP_PRODUCT_CAT_CANONICAL_SCHEMA__ = __M_SP_PRODUCT_CAT_RAW_SCHEMA__


# Set valModels for the different master data sources

# Assign to each field the corresponding validation for __PRODUCT_MASTER_STRUCT_VALIDATIONS__
__PRODUCT_MASTER_STRUCT_VALIDATIONS__ = {
  "PRODUCT_INTERNAL_CODE":digit_val,
  "PRODUCT_NATIONAL_CODE":digit_val,
  "BAR_CODE":digit_val,
  "PRODUCT_NAME":no_val,
  "PRODUCT_DESCRIPTION":no_val,
  "START_DATE":date_val_yyyymmddHHmmss,
  "END_DATE":date_val_yyyymmddHHmmss,
  "MANUFACTURER_CODE":digit_val,
  "OWNBRAND_FLG":yesno_val,
  "OWNBRAND":no_val,
  "LEGAL_CATEGORY":no_val,
  "FAMILY":no_val,
  "IMS_CODE":no_val,
  "ATC_CODE":no_val,
  "LINKED_TO_PRODUCT":digit_val,
  "REPLACED_BY_PRODUCT":digit_val,
  "VAT_TYPE":digit_val,
  "SALES_PRICE_MANUFACTURER":no_val,
  "SALES_PRICE_PHARMACY":no_val,
  "SALES_PRICE_PUBLIC":no_val
}

# Assign to each field the corresponding validation for __PRODUCT_MASTER_CAT_STRUCT_VALIDATIONS__
__PRODUCT_MASTER_CAT_STRUCT_VALIDATIONS__ = {
  "PRODUCT_INTERNAL_CODE":digit_val,
  "BAR_CODE":digit_val,
  "PRODUCT_NAME":no_val,
  "MANUFACTURER_CODE":digit_val,
  "MANUFACTURER_NAME":no_val,
  "LEGAL_CATEGORY":no_val,
  "COMMERCIAL_CATEGORY_L1":no_val,
  "COMMERCIAL_CATEGORY_L2":no_val,
  "COMMERCIAL_CATEGORY_L3":no_val,
  "BRAND":no_val
}

# Assign to each field the corresponding validation for __PHARMACY_MASTER_STRUCT_VALIDATIONS__

__PHARMACY_MASTER_STRUCT_VALIDATIONS__ = {
  "PHARMACY_CODE":digit_val,
  "PHARMACY_ADHERED_CODE":digit_val,
  "PHARMACY_CUSTOMER_CODE":digit_val,
  "POSTAL_CODE":digit_val,
  "CITY":no_val,
  "PROVINCE":digit_val,
  "COUNTRY_CODE":no_val,
  "LONGITUDE":no_val,
  "LATITUDE":no_val,
  "ALPHEGA_FLG":yesno_val,
  "SANIBRICK":digit_val,
  "CIF":no_val,
  "PHARMACY_NAME":no_val
}

# Assign to each field the corresponding validation for __MANUFACTURER_MASTER_STRUCT_VALIDATIONS__

__MANUFACTURER_MASTER_STRUCT_VALIDATIONS__ = {
  "MANUFACTURER_CODE":digit_val,
  "MANUFACTURER_NAME":no_val
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
